# %% [markdown]
# # Bigframes quickstart
#
# BigQuery DataFrames provides a Pythonic DataFrame and machine learning (ML) API powered by the BigQuery engine.
#
# - bigframes.pandas provides a pandas-compatible API for analytics.
# - bigframes.ml provides a scikit-learn-like API for ML.
#
# BigQuery DataFrames is an open-source package.
#
# Read more at: [BigQuery DataFrames](https://cloud.google.com/python/docs/reference/bigframes/latest)

# %%
import bigframes.pandas as bpd

# %%
# Settings based on your plugin configurations. You can change these settings below.
PROJECT_ID = 'pattarav-gke'
REGION = 'us'

bpd.options.bigquery.project = PROJECT_ID
bpd.options.bigquery.location = REGION

# %% [markdown]
# #### Reading datasets from different sources

# %%
# Load data from BigQuery
query_or_table = 'bigquery-public-data.faa.us_airports'
bq_df = bpd.read_gbq(query_or_table)
bq_df.head(20)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=262006177488-ka1m0ue4fptfmt9siejdd5lom7p39upa.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fpydata-google-auth.readthedocs.io%2Fen%2Flatest%2Foauth.html&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform&state=V919T2jAlipD70dimyxtutrOFjzCNJ&prompt=consent&access_type=offline
# Query job b95a986f-82a1-4303-9376-ad7dc0ef9de3 is DONE. 4.5 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=pattarav-gke&j=bq:US:b95a986f-82a1-4303-9376-ad7dc0ef9de3&page=queryresults">Open Job</a>
#    object_id                             global_id faa_identifier  \
# 0       5621  8DEC2E53-9A3E-46D3-888C-FF02EB876EE4           II33
# 1      13550  573B4A61-8209-4D22-ABF9-17B23B108AD4           09PA
# 2       9137  66933F05-41A5-498F-8130-46AE4F5F11CD           5MS8
# 3       3464  1386156A-5403-4004-B4E6-FA8EC746F3C3           FL77
# 4      16372  E3B20EC3-A51E-4820-9719-1FAAB1476EF2            CWC
# 5      13050  D7EB3D11-5DCE-4986-A864-A72AE5A56FF4           7OR8
# 6      13544  044C8EEE-4A66-4D4B-B66A-BC9CA0D2EC3A           6PN7
# 7      14722  D33CE7CC-6BDE-4519-B08B-4D488D380F27            NGT
# 8      12677  324CD582-22B3-4E73-91A3-692214C9F830            BDN
# 9       5168  B5DC813B-7F6F-4817-9D33-B26F287BD885           LL11
# 10      4736  237BF9C5-43D8-4295-A2D2-087A3222923E           ID41
# 11      4279  85BFE13C-D399-4929-98D1-FA46DBAE00CB           02IA
# 12     13106  C83A26A5-335D-4C5A-AA34-CD2C6F292BC9            BFD
# 13     13438  5ED23E9C-C04E-4234-830F-7C71A7E528FC           PN78
# 14     12062  B20567E5-2564-48B7-977D-483D6A33F5B4           1OI6
# 15     15423  BE57E3CC-52A4-486C-ABBE-C0E922BD07A1           8TX0
# 16      2217  5FAAE591-7F25-4ECE-BA1C-0D1FD1165AE2           CA52
# 17     17477  AB9C3F1F-D1FA-40DB-B72F-3AF089086C4D           55WA
# 18     12015  8F09A4F0-02F7-466D-8C73-2693B1D445E9            LPR
# 19     18639  9CB7BB5D-0A4C-4849-A326-23FA47667219           <NA>
#
#                         name   latitude   longitude  \
# 0                  Eickholtz  38.460888  -87.655031
# 1                  Eagle Fld  40.827012  -77.988063
# 2                       Ball  33.873062  -88.723894
# 3               Calusa Ranch   26.05454  -81.067851
# 4          Kickapoo Downtown  33.860623  -98.490407
# 5             Inshallah Intl  44.090432 -119.289693
# 6                      Moyer  41.100286  -75.580835
# 7                Goliad NOLF  28.611613  -97.612578
# 8                  Bend Muni  44.094561 -121.200236
# 9            Edward Hospital  41.760544  -88.153559
# 10                  Stibnite  44.899914   -115.3329
# 11         Boone Co Hospital  42.056291  -93.876483
# 12             Bradford Rgnl  41.802963  -78.639969
# 13  600 Grant Street Rooftop  40.442021  -79.995334
# 14                     Stone  39.770062  -84.416618
# 15                   Hub Fld  31.428394  -96.134868
# 16              Ports O'call  33.732107 -118.276055
# 17           Wilkinson Ranch  46.528061 -120.761403
# 18            Lorain Co Rgnl  41.344286  -82.177643
# 19  Ciudad Camargo Southeast  27.598846 -105.104293
#
#                    airport_geom  elevation icao_id airport_type  ... far_91  \
# 0    POINT (-87.65503 38.46089)      620.0    <NA>     Aerodome  ...  False
# 1    POINT (-77.98806 40.82701)     1780.0    <NA>     Aerodome  ...  False
# 2    POINT (-88.72389 33.87306)      298.0    <NA>     Aerodome  ...  False
# 3    POINT (-81.06785 26.05454)       15.0    <NA>     Aerodome  ...  False
# 4    POINT (-98.49041 33.86062)     1003.0    KCWC     Aerodome  ...  False
# 5   POINT (-119.28969 44.09043)     4560.0    <NA>     Aerodome  ...  False
# 6    POINT (-75.58084 41.10029)     1675.0    <NA>     Heliport  ...  False
# 7    POINT (-97.61258 28.61161)      322.0    KNGT     Aerodome  ...  False
# 8   POINT (-121.20024 44.09456)     3459.5    KBDN     Aerodome  ...  False
# 9    POINT (-88.15356 41.76054)      702.0    <NA>     Heliport  ...  False
# 10   POINT (-115.3329 44.89991)     6539.0    <NA>     Aerodome  ...  False
# 11   POINT (-93.87648 42.05629)     1160.0    <NA>     Heliport  ...  False
# 12   POINT (-78.63997 41.80296)     2143.1    KBFD     Aerodome  ...  False
# 13   POINT (-79.99533 40.44202)     1604.0    <NA>     Heliport  ...  False
# 14   POINT (-84.41662 39.77006)      978.0    <NA>     Aerodome  ...  False
# 15   POINT (-96.13487 31.42839)      361.0    <NA>     Aerodome  ...  False
# 16  POINT (-118.27606 33.73211)        2.0    <NA>     Heliport  ...  False
# 17   POINT (-120.7614 46.52806)     1670.0    <NA>     Aerodome  ...  False
# 18   POINT (-82.17764 41.34429)      793.2    KLPR     Aerodome  ...  False
# 19  POINT (-105.10429 27.59885)     4233.0      MM     Aerodome  ...  False
#
#    far_93 mil_code airspace_analysis us_high  us_low  ak_high  ak_low  \
# 0   False    CIVIL      Not Analyzed   False   False    False   False
# 1   False    CIVIL      No Objection   False   False    False   False
# 2   False    CIVIL       Conditional   False   False    False   False
# 3   False    CIVIL       Conditional   False   False    False   False
# 4   False    CIVIL      Not Analyzed   False    True    False   False
# 5   False    CIVIL      No Objection   False   False    False   False
# 6   False    CIVIL       Conditional   False   False    False   False
# 7   False      MIL      No Objection    True    True    False   False
# 8   False    CIVIL      Not Analyzed    True    True     True   False
# 9   False    CIVIL       Conditional   False   False    False   False
# 10  False    CIVIL      Not Analyzed   False   False    False   False
# 11  False    CIVIL       Conditional   False   False    False   False
# 12  False    CIVIL      Not Analyzed    True    True    False   False
# 13  False    CIVIL      No Objection   False   False    False   False
# 14  False    CIVIL      No Objection   False   False    False   False
# 15  False    CIVIL      No Objection   False   False    False   False
# 16  False    CIVIL       Conditional   False   False    False   False
# 17  False    CIVIL      No Objection   False   False    False   False
# 18   True    CIVIL      No Objection    True    True    False   False
# 19  False    CIVIL      Not Analyzed    True   False    False   False
#
#     us_area pacific
# 0     False   False
# 1     False   False
# 2     False   False
# 3     False   False
# 4     False   False
# 5     False   False
# 6     False   False
# 7     False   False
# 8     False   False
# 9     False   False
# 10    False   False
# 11    False   False
# 12    False   False
# 13    False   False
# 14    False   False
# 15    False   False
# 16    False   False
# 17    False   False
# 18    False   False
# 19    False   False
#
# [20 rows x 27 columns]

# %%
# Load data from GCS
filepath = 'gs://cloud-samples-data/bigquery/us-states/us-states.csv'
gcs_df = bpd.read_csv(filepath)
gcs_df.head()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Load data from GCS
#       2 filepath = 'gs://cloud-samples-data/bigquery/us-states/us-states.csv'
# ----> 3 gcs_df = bpd.read_csv(filepath)
#       4 gcs_df.head()
#
# File /usr/local/lib/python3.9/dist-packages/bigframes/pandas/io/api.py:108, in read_csv(filepath_or_buffer, sep, header, names, index_col, usecols, dtype, engine, encoding, **kwargs)
#      73 def read_csv(
#      74     filepath_or_buffer: str | IO["bytes"],
#      75     *,
#    (...)
#     106     **kwargs,
#     107 ) -> bigframes.dataframe.DataFrame:
# --> 108     return global_session.with_default_session(
#     109         bigframes.session.Session.read_csv,
#     110         filepath_or_buffer=filepath_or_buffer,
#     111         sep=sep,
#     112         header=header,
#     113         names=names,
#     114         index_col=index_col,
#     115         usecols=usecols,
#     116         dtype=dtype,
#     117         engine=engine,
#     118         encoding=encoding,
#     119         **kwargs,
#     120     )
#
# File /usr/local/lib/python3.9/dist-packages/bigframes/core/global_session.py:113, in with_default_session(func, *args, **kwargs)
#     112 def with_default_session(func: Callable[..., _T], *args, **kwargs) -> _T:
# --> 113     return func(get_global_session(), *args, **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/bigframes/session/__init__.py:896, in Session.read_csv(self, filepath_or_buffer, sep, header, names, index_col, usecols, dtype, engine, encoding, **kwargs)
#     890     raise NotImplementedError(
#     891         "'chunksize' and 'iterator' arguments are not supported. "
#     892         f"{constants.FEEDBACK_LINK}"
#     893     )
#     895 if isinstance(filepath_or_buffer, str):
# --> 896     self._check_file_size(filepath_or_buffer)
#     897 pandas_df = pandas.read_csv(
#     898     filepath_or_buffer,
#     899     sep=sep,
#    (...)
#     907     **kwargs,
#     908 )
#     909 return self._read_pandas(pandas_df, "read_csv")
#
# File /usr/local/lib/python3.9/dist-packages/bigframes/session/__init__.py:1054, in Session._check_file_size(self, filepath)
#    1052 max_size = 1024 * 1024 * 1024  # 1 GB in bytes
#    1053 if filepath.startswith("gs://"):  # GCS file path
# -> 1054     client = storage.Client()
#    1055     bucket_name, blob_name = filepath.split("/", 3)[2:]
#    1056     bucket = client.bucket(bucket_name)
#
# File /usr/local/lib/python3.9/dist-packages/google/cloud/storage/client.py:228, in Client.__init__(self, project, credentials, _http, client_info, client_options, use_auth_w_custom_endpoint, extra_headers)
#     225             no_project = True
#     226             project = "<none>"
# --> 228 super(Client, self).__init__(
#     229     project=project,
#     230     credentials=credentials,
#     231     client_options=client_options,
#     232     _http=_http,
#     233 )
#     235 # Validate that the universe domain of the credentials matches the
#     236 # universe domain of the client.
#     237 if self._credentials.universe_domain != self.universe_domain:
#
# File /usr/local/lib/python3.9/dist-packages/google/cloud/client/__init__.py:320, in ClientWithProject.__init__(self, project, credentials, client_options, _http)
#     319 def __init__(self, project=None, credentials=None, client_options=None, _http=None):
# --> 320     _ClientProjectMixin.__init__(self, project=project, credentials=credentials)
#     321     Client.__init__(
#     322         self, credentials=credentials, client_options=client_options, _http=_http
#     323     )
#
# File /usr/local/lib/python3.9/dist-packages/google/cloud/client/__init__.py:268, in _ClientProjectMixin.__init__(self, project, credentials)
#     265     project = getattr(credentials, "project_id", None)
#     267 if project is None:
# --> 268     project = self._determine_default(project)
#     270 if project is None:
#     271     raise EnvironmentError(
#     272         "Project was not passed and could not be "
#     273         "determined from the environment."
#     274     )
#
# File /usr/local/lib/python3.9/dist-packages/google/cloud/client/__init__.py:287, in _ClientProjectMixin._determine_default(project)
#     284 @staticmethod
#     285 def _determine_default(project):
#     286     """Helper:  use default project detection."""
# --> 287     return _determine_default_project(project)
#
# File /usr/local/lib/python3.9/dist-packages/google/cloud/_helpers/__init__.py:152, in _determine_default_project(project)
#     140 """Determine default project ID explicitly or implicitly as fall-back.
#     141
#     142 See :func:`google.auth.default` for details on how the default project
#    (...)
#     149 :returns: Default project if it can be determined.
#     150 """
#     151 if project is None:
# --> 152     _, project = google.auth.default()
#     153 return project
#
# File /usr/local/lib/python3.9/dist-packages/google/auth/_default.py:697, in default(scopes, request, quota_project_id, default_scopes)
#     689             _LOGGER.warning(
#     690                 "No project ID could be determined. Consider running "
#     691                 "`gcloud config set project` or setting the %s "
#     692                 "environment variable",
#     693                 environment_vars.PROJECT,
#     694             )
#     695         return credentials, effective_project_id
# --> 697 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
# Loading from local file
filepath = 'Change this to the local file path'
local_df = bpd.read_csv(filepath)
local_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Loading from local file
#       2 filepath = 'Change this to the local file path'
# ----> 3 local_df = bpd.read_csv(filepath)
#       4 local_df.head()
#
# File /opt/dataproc/conda/lib/python3.12/site-packages/bigframes/pandas/__init__.py:460, in read_csv(filepath_or_buffer, sep, header, names, index_col, usecols, dtype, engine, encoding, **kwargs)
#     425 def read_csv(
#     426     filepath_or_buffer: str | IO["bytes"],
#     427     *,
#    (...)
#     458     **kwargs,
#     459 ) -> bigframes.dataframe.DataFrame:
# --> 460     return global_session.with_default_session(
#     461         bigframes.session.Session.read_csv,
#     462         filepath_or_buffer=filepath_or_buffer,
#     463         sep=sep,
#     464         header=header,
#     465         names=names,
#     466         index_col=index_col,
#     467         usecols=usecols,
#     468         dtype=dtype,
#     469         engine=engine,
#     470         encoding=encoding,
#     471         **kwargs,
#     472     )
#
# File /opt/dataproc/conda/lib/python3.12/site-packages/bigframes/core/global_session.py:113, in with_default_session(func, *args, **kwargs)
#     112 def with_default_session(func: Callable[..., _T], *args, **kwargs) -> _T:
# --> 113     return func(get_global_session(), *args, **kwargs)
#
# File /opt/dataproc/conda/lib/python3.12/site-packages/bigframes/session/__init__.py:1259, in Session.read_csv(self, filepath_or_buffer, sep, header, names, index_col, usecols, dtype, engine, encoding, **kwargs)
#    1253     raise NotImplementedError(
#    1254         "'chunksize' and 'iterator' arguments are not supported. "
#    1255         f"{constants.FEEDBACK_LINK}"
#    1256     )
#    1258 if isinstance(filepath_or_buffer, str):
# -> 1259     self._check_file_size(filepath_or_buffer)
#    1260 pandas_df = pandas.read_csv(
#    1261     filepath_or_buffer,
#    1262     sep=sep,
#    (...)
#    1270     **kwargs,
#    1271 )
#    1272 return self._read_pandas(pandas_df, "read_csv")
#
# File /opt/dataproc/conda/lib/python3.12/site-packages/bigframes/session/__init__.py:1414, in Session._check_file_size(self, filepath)
#    1412     file_size = blob.size
#    1413 else:  # local file path
# -> 1414     file_size = os.path.getsize(filepath)
#    1416 if file_size > max_size:
#    1417     # Convert to GB
#    1418     file_size = round(file_size / (1024**3), 1)
#
# File <frozen genericpath>:62, in getsize(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Change this to the local file path'
